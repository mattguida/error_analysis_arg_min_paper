# %%
import pandas as pd
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, classification_report
from collections import Counter, defaultdict
import json, csv
import numpy as np
import xmltodict
from sklearn.dummy import DummyClassifier
import random
import os
from statistics import mean, stdev
import warnings 
from scipy.stats import ttest_rel, levene
from collections import defaultdict
from typing import List, Dict, Tuple
from scipy import stats
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from rouge_score import rouge_scorer

warnings.filterwarnings('ignore')

# %% [markdown]
# Task 3, GPT4o - 0s (strongest) -- FP and FN

# %%
def get_kshot_examples(dataset, shots, split):
    """Get k-shot examples for a specific dataset, shot count and split."""
    if shots == "0":
        return []
    
    dataset_name = dataset.upper()
    shots_name = f"{shots}shot"
    
    filename = f"/Users/guida/llm_argument_tasks/run_all_k_shots/k-shots/{dataset_name}_all_arguments_main_{shots_name}_split_{split}.csv"
    filepath = os.path.join("run_all_k_shots", "k-shots", filename)
    
    df = pd.read_csv(filepath)
    return df['id'].tolist()

# %%
def get_gold(binarize, task, data, kshot_examples, data_dir='/Users/guida/llm_argument_tasks/clean_data/'):
    data = open(f'{data_dir}{data.upper()}.xml', 'r').read()
    data = xmltodict.parse(data)
    
    gold = {}
    # binary labels (3 => 0; all else => 1)
    if task == 1:
        for comarg in data['document']['unit']:
            ii = comarg['@id']
            label = comarg['label']
            if label == '3' and ii not in kshot_examples:
                gold[ii] = 0
            elif ii not in kshot_examples:
                gold[ii] = 1
                
    # types of use
    # binary: 4/5 = 5 and 1/2 = 1 and 3 = delete
    # 4-way: 1, 2, 4, 5, 3 = delete
    if task == 2:
        for comarg in data['document']['unit']:
            ii = comarg['@id']
            label = comarg['label']
            if binarize:
                if label in ['1','2']:
                    label = 1
                elif label in ['4','5']:
                    label = 5
            if label != '3' and ii not in kshot_examples:
                gold[ii] = int(label)
    return gold

# %%
def get_predictions(fname, gold): 
    preds = pd.read_json(fname, lines=True).to_dict()
    preds = {preds['id'][i]: preds['label'][i] for i in preds['id'].keys()}
   
    gold_list = []
    pred_list = []
    ids = []

    gold_ids = set(gold.keys())
    pred_ids = set(preds.keys())
    
   # print(f"Gold IDs count: {len(gold_ids)}, Prediction IDs count: {len(pred_ids)}")
   # print(f"Overlap count: {len(gold_ids.intersection(pred_ids))}")
   # print(f"Gold-only IDs: {len(gold_ids - pred_ids)}, Pred-only IDs: {len(pred_ids - gold_ids)}")


    for k in set(list(gold.keys()) + list(preds.keys())):
        if k in gold and k in preds:
            ids.append(k)
            gold_list.append(gold[k])
            pred_list.append(preds[k])

    return gold_list, pred_list, ids

def evaluate(gold, predicted):
    prec = precision_score(gold, predicted, average='macro', zero_division=0.0)
    rec = recall_score(gold, predicted, average='macro', zero_division=0.0)
    f1 = (2 * prec * rec) / (prec + rec) if (prec + rec) > 0 else 0.0
    support = len(gold)
    cm = confusion_matrix(gold, predicted)
    return prec, rec, f1, support, cm

# %%
# !pwd
# Out:
# /Users/guida/llm_argument_tasks/evaluation-lea/error_analysis

# %%
def get_full_argument_context(dataset, unit_id):
    data_dir = '/Users/guida/llm_argument_tasks/clean_data/'
    data = open(f'{data_dir}{dataset.upper()}.xml', 'r').read()
    data = xmltodict.parse(data)
    for unit in data['document']['unit']:
        if unit['@id'] == unit_id:
            return {
                'argument': unit['argument']['text'],
                'stance': unit['argument']['stance'],
                'comment': unit['comment']['text']
            }
    return None

def evaluate_all_splits_with_errors():
    results = []
    error_cases = []
    correct_cases = []
    for dataset in ["gm", "ugip"]:
        for task in ["binary"]:
            print(f"\n===== {task} {dataset} =====")
            dataset_results = []
            if task == "binary":
                binarize = True
                base_path = "/Users/guida/llm_argument_tasks/evaluation-lea/task2_binary_outputs"
                subtask_folder = "SubtaskA"
                tag = "2ways"
            else:
                binarize = False
                base_path = "/../task2_full_scale_outputs"
                subtask_folder = "SubtaskB"
                tag = "5ways"
            gold_raw = get_gold(binarize=binarize, task=2, data=dataset, kshot_examples=[])
            for model in ["gpt4"]:
                pred_file_0 = f"comarg_{dataset}_relation_identification_{tag}_{model}_0shot.jsonl"
                pred_path_0 = os.path.join(base_path, model, "0-s", pred_file_0)
                try:
                    gold, pred, ids = get_predictions(pred_path_0, gold_raw)
                    labels = np.unique(np.concatenate([gold, pred]))
                    pr, re, f1, supp, cm = evaluate(gold, pred)
                    result = {
                        'dataset': dataset,
                        'model': model,
                        'split': 0,
                        'shot': "0",
                        'precision': pr,
                        'recall': re,
                        'f1': f1,
                        'support': supp,
                        'confusion_matrix': cm
                    }
                    results.append(result)
                    dataset_results.append(result)
                    for i, (g, p, id_) in enumerate(zip(gold, pred, ids)):

                        context = get_full_argument_context(dataset, id_)
                        entry = {
                                'dataset': dataset,
                                'split': 0,
                                'id': id_,
                                'gold': g,
                                'pred': p,
                                'error_type': 'FP' if p == 1 and g == 0 else 'FN',
                                'argument': context['argument'],
                                'stance': context['stance'],
                                'comment': context['comment']
                        }

                        if g != p:
                            entry['error_type'] = 'FP' if p == 1 and g == 0 else 'FN'
                            error_cases.append(entry)
                        else:
                            entry['error_type'] = 'correct'
                            correct_cases.append(entry)
                except FileNotFoundError:
                    print(f"Missing file: {pred_path_0}")
                except Exception as e:
                    print(f"Error processing {pred_path_0}: {str(e)}")
        print(f"\n{'='*20} Aggregate Results for {model} {'='*20}")
        dataset_df = pd.DataFrame(dataset_results)
        agg_results = dataset_df.groupby(['model', 'shot']).agg({
            'precision': ['mean', 'std'],
            'recall': ['mean', 'std'],
            'f1': ['mean', 'std']
        }).round(3)
        print(agg_results)
    return agg_results, pd.DataFrame(error_cases), pd.DataFrame(correct_cases)

agg_results, error_comarg, correct_comarg = evaluate_all_splits_with_errors()
# Out:
# ===== binary gm =====
#
# ==================== Aggregate Results for gpt4 ====================
#            precision     recall         f1
#                 mean std   mean std   mean std
# model shot
# gpt4  0        0.932 NaN  0.954 NaN  0.943 NaN
#
# ===== binary ugip =====
#
# ==================== Aggregate Results for gpt4 ====================
#            precision     recall         f1
#                 mean std   mean std   mean std
# model shot
# gpt4  0        0.966 NaN  0.971 NaN  0.969 NaN

# %%
all_cases = pd.concat([error_comarg, correct_comarg], ignore_index=True)
all_cases
# Out:
#     dataset  split             id  gold  pred error_type  \
# 0        gm      0        107arg1     5     1         FN
# 1        gm      0         95arg2     5     1         FN
# 2        gm      0        137arg5     5     1         FN
# 3        gm      0        148arg1     5     1         FN
# 4        gm      0         60arg7     5     1         FN
# ..      ...    ...            ...   ...   ...        ...
# 751    ugip      0  414721730arg1     1     1    correct
# 752    ugip      0  414721661arg2     5     5    correct
# 753    ugip      0  414721876arg2     5     5    correct
# 754    ugip      0  414721809arg6     5     5    correct
# 755    ugip      0  414721846arg1     5     5    correct
#
#                                               argument stance  \
# 0    Gay couples can declare their union without re...    Con
# 1    Gay couples should be able to take advantage o...    Pro
# 2      Major world religions are against gay marriages    Con
# 3    Gay couples can declare their union without re...    Con
# 4         Marriage should be between a man and a woman    Con
# ..                                                 ...    ...
# 751                   Separation of state and religion    Con
# 752  Removing under god would promote religious tol...    Con
# 753  Removing under god would promote religious tol...    Con
# 754  America is based on democracy and the pledge s...    Pro
# 755                   Separation of state and religion    Con
#
#                                                comment
# 0    Marriage is a union between MAN and WIFE in th...
# 1    It is not possible for a gay couple to enter i...
# 2    So I want to know whats next. Are we going to ...
# 3    The ideal setting in which to raise a child is...
# 4    I do believe that if you love each other that ...
# ..                                                 ...
# 751  The words Under God should not be removed from...
# 752  It should be taken out. This is NOT a christia...
# 753  I am against having the statement Under God in...
# 754  Since the majority of the people in America be...
# 755  'God' is not an irrefutable fact; it is a pers...
#
# [756 rows x 9 columns]

# %%
all_cases['error_type'].value_counts()
# Out:
# error_type
# correct    721
# FN          35
# Name: count, dtype: int64

# %%
error_comarg
# Out:
#    dataset  split             id  gold  pred error_type  \
# 0       gm      0        107arg1     5     1         FN
# 1       gm      0         95arg2     5     1         FN
# 2       gm      0        137arg5     5     1         FN
# 3       gm      0        148arg1     5     1         FN
# 4       gm      0         60arg7     5     1         FN
# 5       gm      0        119arg2     5     1         FN
# 6       gm      0         85arg5     5     1         FN
# 7       gm      0        127arg1     5     1         FN
# 8       gm      0         42arg1     5     1         FN
# 9       gm      0          7arg1     5     1         FN
# 10      gm      0        108arg2     5     1         FN
# 11      gm      0          7arg2     5     1         FN
# 12      gm      0         26arg2     5     1         FN
# 13      gm      0        117arg1     5     1         FN
# 14      gm      0        173arg7     5     1         FN
# 15      gm      0         53arg5     5     1         FN
# 16      gm      0        173arg5     5     1         FN
# 17      gm      0         60arg4     5     1         FN
# 18      gm      0         60arg2     5     1         FN
# 19      gm      0         78arg1     5     1         FN
# 20      gm      0         18arg1     5     1         FN
# 21      gm      0        164arg4     5     1         FN
# 22      gm      0         77arg2     5     1         FN
# 23      gm      0         13arg2     5     1         FN
# 24      gm      0        190arg2     5     1         FN
# 25    ugip      0  414721684arg3     5     1         FN
# 26    ugip      0  414721990arg5     5     1         FN
# 27    ugip      0  414721866arg1     5     1         FN
# 28    ugip      0  414721839arg4     5     1         FN
# 29    ugip      0  414721831arg6     5     1         FN
# 30    ugip      0  414721800arg4     5     1         FN
# 31    ugip      0  414721886arg4     1     5         FN
# 32    ugip      0  414721951arg1     5     1         FN
# 33    ugip      0  414721976arg4     5     1         FN
# 34    ugip      0  414721924arg2     1     5         FN
#
#                                              argument stance  \
# 0   Gay couples can declare their union without re...    Con
# 1   Gay couples should be able to take advantage o...    Pro
# 2     Major world religions are against gay marriages    Con
# 3   Gay couples can declare their union without re...    Con
# 4        Marriage should be between a man and a woman    Con
# 5   Gay couples should be able to take advantage o...    Pro
# 6     Major world religions are against gay marriages    Con
# 7   Gay couples can declare their union without re...    Con
# 8   Gay couples can declare their union without re...    Con
# 9   Gay couples can declare their union without re...    Con
# 10  Gay couples should be able to take advantage o...    Pro
# 11  Gay couples should be able to take advantage o...    Pro
# 12  Gay couples should be able to take advantage o...    Pro
# 13  Gay couples can declare their union without re...    Con
# 14       Marriage should be between a man and a woman    Con
# 15    Major world religions are against gay marriages    Con
# 16    Major world religions are against gay marriages    Con
# 17  It is discriminatory to refuse gay couples the...    Pro
# 18  Gay couples should be able to take advantage o...    Pro
# 19  Gay couples can declare their union without re...    Con
# 20  Gay couples can declare their union without re...    Con
# 21  It is discriminatory to refuse gay couples the...    Pro
# 22  Gay couples should be able to take advantage o...    Pro
# 23  Gay couples should be able to take advantage o...    Pro
# 24  Gay couples should be able to take advantage o...    Pro
# 25  Under God  is part of American tradition and h...    Pro
# 26    Implies ultimate power on the part of the state    Con
# 27                   Separation of state and religion    Con
# 28  Likely to be seen as a state sanctioned condem...    Pro
# 29  America is based on democracy and the pledge s...    Pro
# 30  Likely to be seen as a state sanctioned condem...    Pro
# 31  Likely to be seen as a state sanctioned condem...    Pro
# 32                   Separation of state and religion    Con
# 33  Likely to be seen as a state sanctioned condem...    Pro
# 34  Removing under god would promote religious tol...    Con
#
#                                               comment
# 0   Marriage is a union between MAN and WIFE in th...
# 1   It is not possible for a gay couple to enter i...
# 2   So I want to know whats next. Are we going to ...
# 3   The ideal setting in which to raise a child is...
# 4   I do believe that if you love each other that ...
# 5   No, gay marriage will never be legal ,marriage...
# 6   If we address gay marriage on the basis of rel...
# 7   People need to realize that gay marriage is wr...
# 8   Hell to the No.  Marriage has always been defi...
# 9   Absolutely No. Who are we to rewrite the creat...
# 10  Marriage is for heterosexuals.  Other contract...
# 11  Absolutely No. Who are we to rewrite the creat...
# 12  Gay marriage is different from that of interra...
# 13  No one can dictate who one loves. That is not ...
# 14  You will never change people's minds about the...
# 15  I am not gay and hate gay bashing. I am very r...
# 16  You will never change people's minds about the...
# 17  I do believe that if you love each other that ...
# 18  I do believe that if you love each other that ...
# 19  I'm con because gay marriage is against the mo...
# 20  Different people have different thoughts about...
# 21  Well'if we start legalizing gay marriage,that ...
# 22  I'm con actually not because I think governmen...
# 23  By being GAY you are agreeing to certain unavo...
# 24  marriage is a religious construct mandated by ...
# 25  As a general proposition, government should be...
# 26  The phrase 'under God' acts as a limit on what...
# 27  Theocracy is in our midst---7.US churches have...
# 28  I do believe that under God should be left in ...
# 29  Religious bondage shackles and debilitates the...
# 30  The words 'under God' aren't hurting anyone. I...
# 31  'God' is not an irrefutable fact; it is a pers...
# 32  Since it is a governmental thing, then no.  I'...
# 33  yes im tired of people getting worried about o...
# 34  Instead of taking out 'under god,' ADD, 'or no...

# %%
all_cases['gold'] = all_cases['gold'].replace({5: "Support", 1: "Attack"})
all_cases['pred'] = all_cases['pred'].replace({5: "Support", 1: "Attack"})

all_cases
# Out:
#     dataset  split             id     gold     pred error_type  \
# 0        gm      0        107arg1  Support   Attack         FN
# 1        gm      0         95arg2  Support   Attack         FN
# 2        gm      0        137arg5  Support   Attack         FN
# 3        gm      0        148arg1  Support   Attack         FN
# 4        gm      0         60arg7  Support   Attack         FN
# ..      ...    ...            ...      ...      ...        ...
# 751    ugip      0  414721730arg1   Attack   Attack    correct
# 752    ugip      0  414721661arg2  Support  Support    correct
# 753    ugip      0  414721876arg2  Support  Support    correct
# 754    ugip      0  414721809arg6  Support  Support    correct
# 755    ugip      0  414721846arg1  Support  Support    correct
#
#                                               argument stance  \
# 0    Gay couples can declare their union without re...    Con
# 1    Gay couples should be able to take advantage o...    Pro
# 2      Major world religions are against gay marriages    Con
# 3    Gay couples can declare their union without re...    Con
# 4         Marriage should be between a man and a woman    Con
# ..                                                 ...    ...
# 751                   Separation of state and religion    Con
# 752  Removing under god would promote religious tol...    Con
# 753  Removing under god would promote religious tol...    Con
# 754  America is based on democracy and the pledge s...    Pro
# 755                   Separation of state and religion    Con
#
#                                                comment
# 0    Marriage is a union between MAN and WIFE in th...
# 1    It is not possible for a gay couple to enter i...
# 2    So I want to know whats next. Are we going to ...
# 3    The ideal setting in which to raise a child is...
# 4    I do believe that if you love each other that ...
# ..                                                 ...
# 751  The words Under God should not be removed from...
# 752  It should be taken out. This is NOT a christia...
# 753  I am against having the statement Under God in...
# 754  Since the majority of the people in America be...
# 755  'God' is not an irrefutable fact; it is a pers...
#
# [756 rows x 9 columns]

# %%
all_cases.to_csv('../qualitative_analysis/error_and_correct_t3.csv', index=False)
